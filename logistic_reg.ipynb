# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:/LearningConcepts/intelipaat/ML models assignments/Logistics Regression Quiz/census-income .csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.rename(columns={'annual_income' : "Annual Income"}, inplace = True)

# %%
df.replace('?', np.nan, inplace = True )

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4262)

# %%
import numpy as np

df.replace('?', np.nan, inplace=True)
df = df.dropna()

# %%
df[(df['occupation'] == 'Tech-support') & (df['Annual Income'] == '>50K')].shape[0]
# Out:
# 278

# %%
import numpy as np

df.replace('?', np.nan, inplace=True)
df = df.dropna()

df[(df['workclass'] == 'Private') &
   (df['native-country'] != 'United-States')].shape[0]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_34540\30492385.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('?', np.nan, inplace=True)
# 2151

# %%
df[(df['workclass'] == 'Private') & (df['native-country'] != 'United-States')].shape[0]
# Out:
# 2151

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Annual Income'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df[(df['annual_income'] == '<=50K') |
   (df['hours-per-week'] >= 40)].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annual_income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[411], line 1
# ----> 1 df[(df['annual_income'] == '<=50K') |
# ...

# %%
df[(df['occupation'] == 'Tech-support') &
   (df['annual_income'] == '>50k')].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annual_income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[374], line 2
#       1 df[(df['occupation'] == 'Tech-support') &
# ...

# %%
df['annual_income'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annual_income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[375], line 1
# ----> 1 df['annual_income'].value_counts()
#
# ...

# %%
df[(df['occupation'] == 'Tech-support') &
   (df['annual_income'] == '>50K')].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annual_income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[376], line 2
#       1 df[(df['occupation'] == 'Tech-support') &
# ...

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 27504
# Mexico                          610
# Philippines                     188
# Germany                         128
# Puerto-Rico                     109
# Canada                          107
# El-Salvador                     100
# India                           100
# Cuba                             92
# England                          86
# Jamaica                          80
# South                            71
# Italy                            68
# China                            68
# Dominican-Republic               67
# Vietnam                          64
# Guatemala                        63
# Japan                            59
# Columbia                         56
# Poland                           56
# Haiti                            42
# Iran                             42
# Taiwan                           42
# Portugal                         34
# Nicaragua                        33
# ...

# %%
[df['occupation'].nunique()]
# Out:
# [14]

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4038
# Craft-repair         4030
# Exec-managerial      3992
# Adm-clerical         3721
# Sales                3584
# Other-service        3212
# Machine-op-inspct    1966
# Transport-moving     1572
# Handlers-cleaners    1350
# Farming-fishing       989
# Tech-support          912
# Protective-serv       644
# Priv-house-serv       143
# Armed-Forces            9
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education-num   30162 non-null  int64
#  5   marital-status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital-gain    30162 non-null  int64
#  11  capital-loss    30162 non-null  int64
#  12  hours-per-week  30162 non-null  int64
#  13  native-country  30162 non-null  object
#  14  Annual Income   30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Annual Income'],
#       dtype='object')

# %%
import numpy as np

probs = df['Htype'].value_counts(normalize=True)

entropy = -1 * np.sum(np.log2(probs) * probs)

print(entropy)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Htype'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[380], line 3
#       1 import numpy as np
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Annual Income     0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype != 'object':
        sns.boxplot(df[col])
        plt.xlabel(col)
        plt.show()

# %%
sns.heatmap(df.corr(numeric_only = True) , annot = True )
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_34540\133371954.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = le.fit_transform(df[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_34540\133371954.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = le.fit_transform(df[col])
# C:\Users\hp\AppData\Local\Temp\ipykernel_34540\133371954.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['annual_income'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'annual_income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[383], line 1
# ----> 1 df['annual_income'].nunique()
#
# ...

# %%
X = df.drop(columns = 'annual_income')
y = df['annual_income']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[384], line 1
# ----> 1 X = df.drop(columns = 'annual_income')
#       2 y = df['annual_income']
#
# File c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

model = LogisticRegression()
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 0)
model.fit(X_train,y_train)
# Out:
# c:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
k = model.predict(X_test)

# %%
from sklearn.metrics import *
print(accuracy_score(y_test, k))
# Out:
# 0.7926842745054702

# %%
print(le.classes_)
# Out:
# ['<=50K' '>50K']

# %%
print(classification_report(y_test, k))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88      6764
#            1       0.80      0.24      0.37      2285
#
#     accuracy                           0.79      9049
#    macro avg       0.80      0.61      0.62      9049
# weighted avg       0.79      0.79      0.75      9049

# %%
cm = confusion_matrix(y_test, k)
cm
# Out:
# array([[6627,  137],
#        [1739,  546]])

# %%
6627 + 546
# Out:
# 7173

# %%
# true negative    false positive
# false positive   true negative
# Out:
# 6764

# %%
model.predict_proba(X_test)
# Out:
# array([[0.79856193, 0.20143807],
#        [0.77331828, 0.22668172],
#        [0.26801941, 0.73198059],
#        ...,
#        [0.83323798, 0.16676202],
#        [0.77895257, 0.22104743],
#        [0.82651364, 0.17348636]])

# %%
How many records present with the following conditions 
age >= 25 and age <= 50, and inplans equals ‘bank’ and Cpur
 is either ‘Business’ or ‘electronics’ and foreign as ‘yes’?

# %%
pd.get_dummies(df).shape
# Out:
# (30162, 15)

# %%
import pandas as pd

df2 = pd.read_excel(
    r"D:/LearningConcepts/intelipaat/ML models assignments/Logistics Regression Quiz/CreditWorthiness.xlsx"
)

df2.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3
# 0                                                NaN
# 1                                          Objective
# 2                                                NaN
# 3                                                NaN
# 4  Cautious plc is in the business of providing c...

# %%
xls = pd.ExcelFile(
    r"D:\LearningConcepts\intelipaat\ML models assignments\Logistics Regression Quiz\CreditWorthiness.xlsx"
)

print(xls.sheet_names)
# Out:
# ['Objective', 'Variables ', 'Data']

# %%
df2 = pd.read_excel(
    r"D:\LearningConcepts\intelipaat\ML models assignments\Logistics Regression Quiz\CreditWorthiness.xlsx",
    sheet_name="Data"
)

df2.head()
# Out:
#                   Cbal  Cdur                   Chist         Cpur    Camt  \
# 0      0 <= Rs. < 2000     9    all settled till now     Business   13790
# 1      0 <= Rs. < 2000    15   dues not paid earlier  electronics   15250
# 2      0 <= Rs. < 2000    36  none taken/all settled     Business   19410
# 3      0 <= Rs. < 2000    48  none taken/all settled     Business  144090
# 4  no checking account    24    all settled till now  electronics   31690
#
#                  Sbal               Edur  InRate  \
# 0          Rs. < 1000       1 to 4 years       2
# 1  no savings account  more than 7 years       4
# 2          Rs. < 1000  more than 7 years       4
# 3          Rs. < 1000       1 to 4 years       2
# 4          Rs. < 1000   less than 1 year       4
#
#                                        MSG        Oparties  ...  \
# 0                  married or widowed male          no one  ...
# 1                              single male  yes, guarantor  ...
# ...

# %%
import numpy as np

probs = df2['Htype'].value_counts(normalize=True)

entropy = -1 * np.sum(np.log2(probs) * probs)

print(entropy)
# Out:
# 1.1390117663236383

# %%
pd.get_dummies(df2).shape[1]
# Out:
# 65

# %%
df2[
    (df2['age'] >= 25) &
    (df2['age'] <= 50) &
    (df2['inPlans'] == 'bank') &
    (df2['Cpur'].isin(['Business', 'electronics'])) &
    (df2['foreign'] == 'yes')
].shape[0]
# Out:
# 0
