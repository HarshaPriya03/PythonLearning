# %%
n=10
r=5
p=100

A=p*(1+r/100)**n
print(f"{A:.2f}")


# b
# Out:
# 162.89

# %%
A=10
B=20
Str = "There are {} students in the class, with {} who play at least one sport."
print(Str.format(A,B))

# a
# Out:
# There are 10 students in the class, with 20 who play at least one sport.

# %%
print(" It goes without saying, \“Time is Money\”, and none can deny it.")

# a
# Out:
#  It goes without saying, \“Time is Money\”, and none can deny it.

# %%
x = lambda a,b: a//b
print(x(10,3))

# b
# Out:
# 3

# %%
A = 10
B = 12
print("Smaller") if A == B else print("Greater") if A < B else print("True")

# c
# Out:
# Greater

# %%
import os
import numpy as np
my_list1=[2,7,3,5,4,6]
print(my_list1)
arr_1=np.array(my_list1,dtype =int)
print(arr_1)

# a
# Out:
# [2, 7, 3, 5, 4, 6]
# [2 7 3 5 4 6]

# %%
string="Machine Learning"
# string[slice(8,13)]
string[slice(8,13,1)]

# d
# Out:
# 'Learn'

# %%
l=[]
for i in range(10,26,4):
    l.append(i)
print(l)


# b
# Out:
# [10, 14, 18, 22]

# %%
if 18 in l:
    print(l.index(18))

# b
# Out:
# 2

# %%
num1=5**4
num2=pow(5,4)
print(num1,num2)

if num1==num2:
    print("Both are equal")

# a
# Out:
# 625 625
# Both are equal

# %%
# Trying to access a variable which has not been defined

print(a)

#a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 # Trying to access a variable which has not been defined
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
x="string"
int(x)

# c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 x="string"
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: 'string'

# %%
#  b  -- A file or directory is requested but does not exist in the working directory

# %%
z=  "ID-5632"
print(type(z))

# b  - string
# Out:
# <class 'str'>

# %%
#  d  - All of the above

# %%
# Choose the symbol/s that does not have the ability to convert any values to string?
# answer: #

# %%
Country={"India":"New Delhi","china":"Beijing","Japan":"Tokyo","Qatar":"Doha","France":"Marseilles"}
for country,capital in Country.items():
    print(f"The capital of {country} is {capital}")
# Out:
# The capital of India is New Delhi
# The capital of china is Beijing
# The capital of Japan is Tokyo
# The capital of Qatar is Doha
# The capital of France is Marseilles

# %%
Country["France"]="Paris"
print(Country)
# Out:
# {'India': 'New Delhi', 'china': 'Beijing', 'Japan': 'Tokyo', 'Qatar': 'Doha', 'France': 'Paris'}

# %%
Country={"India":"New Delhi","china":"Beijing","Japan":"Tokyo","Qatar":"Doha","France":"Marseilles"}
for country,capital in Country.items():
    print(f"The capital of {country} is {capital}")

Country.update({'France': 'Paris'})
for country, capital in Country.items():
    print(f"The capital of {country} is {capital}")
# Out:
# The capital of India is New Delhi
# The capital of china is Beijing
# The capital of Japan is Tokyo
# The capital of Qatar is Doha
# The capital of France is Marseilles
# The capital of India is New Delhi
# The capital of china is Beijing
# The capital of Japan is Tokyo
# The capital of Qatar is Doha
# The capital of France is Paris

# %%
tuple_1 = (1,5,6,7,8)
tuple_2 = (8,9,4)


tuple_1[3] = 45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       1 tuple_1 = (1,5,6,7,8)
#       2 tuple_2 = (8,9,4)
# ----> 5 tuple_1[3] = 45
#
# TypeError: 'tuple' object does not support item assignment

# %%
S={1,2,3,4,4,4,5,6}
print(len(S))

# ans: 6
# Out:
# 6

# %%
def triplets(N):
    for a in range(1,N+1):
        for b in range(a,N+1):
            for c in range(b,N+1):
                if a**2 + b**2 == c**2:
                    print(a,b,c)
triplets(10)
# Out:
# 3 4 5
# 6 8 10
