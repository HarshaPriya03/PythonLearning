# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaPriya03/PythonLearning/blob/main/HR_Analytics_Case_Study_07_02_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/employe (1).csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (11991, 10)

# %% [markdown]
# **How avgMonthlyHours is affecting the employee attrition rate?**

# %%
sns.histplot(data=df,x='avgMonthlyHours',hue='left')
plt.show()

# %% [markdown]
# # **Inference:**
#
# Give the Employee avg Mothly Hours between 100-200.
#
# Avoid giving avgMothly Hours 300 to the employees as they are leaving.

# %% [markdown]
# **How the time spent in the company is affecting the employee attrition rate?**

# %%
sns.countplot(data=df,x='timeSpent.company',hue='left')
plt.show()

# %% [markdown]
# # **Inference:**
#
# The people/employee who are frehsers they are staying in the company.
#
# The people who got some experince they are most likely to leave the company as they get better opprotunity at any other place.
#
# The people who have the experiennce of 3-6 years they are leaviing the company.

# %% [markdown]
# **How the no of projects is affecting the employee attrition rate?**

# %%
sns.countplot(data=df,x='numberOfProjects',hue='left')
plt.show()

# %% [markdown]
# # **Inference:**
#
# Give the number of projects between 3-5 so that they will stay in the company and avoid giving burden to the employee.

# %% [markdown]
# **How the promotion in Last 5 years is affecting the employee attritionn rate?**

# %%
sns.countplot(data=df,x='promotionInLast5years',hue='left')
plt.show()

# %% [markdown]
# # **Inference:**
#
# Employees who did not receive a promotion in the last five years show a significantly higher attrition rate compared to those who were promoted
#
# Give the proper promotions to the employee so that they will not leave the company.

# %% [markdown]
# **How the workaccident affects the employee attrition rate?**

# %%
sns.countplot(data=df,x='workAccident',hue='left')
plt.show()

# %% [markdown]
# # **Inference:**
#
# Employees who had a work accident have less attrition rate compare to who do not have work accident those people are more likey to leave
#
# Work accident does not have much impact on the eemployees attrition rate.

# %% [markdown]
# **How the Department is affecting the attrition Rate?**

# %%
sns.countplot(data=df,x='dept',hue='left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Inference:**
#
# Most of the people are from sales,technichal and support so we should more focus on these department people as they are leaving.

# %% [markdown]
# **How Salary is affecting the employee attrition rate.**

# %%
sns.countplot(data=df,x='salary',hue='left')
plt.show()

# %% [markdown]
# # **Inference:**
#
# Low salary has the High Attrition.
#
# High Salary people leaving the company is significantly less.
#
# Medium to High salary can help emp to stay in same company.
#
# Give the proper salary to the employee as per their performance.

# %% [markdown]
# # Assesment:
#
# Create a short, professional HR Analytics report that caan shared with senior Stakeholders to understand:
#
# Why empployees are leaving.
#
# What actions HR should take to reduce the attrition.
#
# Create a word document that include:
#
# Graphs
#
# Scrrenshots of the graphs
#
# Clear business-focused insight below each graph.
