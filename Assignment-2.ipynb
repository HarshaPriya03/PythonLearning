# %%
class Employee:
    def __init__(self, EmployeeID, Gender, Salary, PerformanceRating):
        self.EmployeeID = EmployeeID
        self.Gender = Gender
        self.Salary = Salary
        self.PerformanceRating = PerformanceRating
    def  get(self):
        print("EmployeeID:", self.EmployeeID)
        print("Gender:", self.Gender)
        print("Salary:", self.Salary)
        if self.PerformanceRating > 5:
            print("PerformanceRating:", self.PerformanceRating,"Cant be greater than 5")

class JoiningDetail:
    def __init__(self,DateOfJoining):
        self.DateOfJoining = DateOfJoining
    def getDoj(self):
        print("Date of Joining:", self.DateOfJoining)

class Information(Employee, JoiningDetail):
    def __init__(self, EmployeeID, Gender, Salary, PerformanceRating, DateOfJoining):
        Employee.__init__(self, EmployeeID,Gender, Salary, PerformanceRating)
        JoiningDetail.__init__(self, DateOfJoining)
    
    def get_details(self):
        # super().get()   
        # self.getDoj()
        Employee.get(self)
        JoiningDetail.getDoj(self)

    # def readData(self):
    #     self.EmployeeID = int(input("Enter Employee ID: "))
    #     self.Gender = input("Enter Gender: ")
    #     self.Salary = int(input("Enter Salary: "))
    #     self.PerformanceRating = int(input("Enter Performance Rating: "))
    #     self.DateOfJoining = input("Enter Date of Joining (YYYY-MM-DD): ")
    
    # def top_3_performers(self):
    #     performers = [Emp1, Emp2, Emp3, Emp4, Emp5]
    #     performers.sort(key=lambda x: x.PerformanceRating, reverse=True)
    #     top_3 = performers[:3]
    #     print("Top 3 Performers:")
    #     for emp in top_3:
    #         print(f"Employee ID: {emp.EmployeeID}, Performance Rating: {emp.PerformanceRating}")

    def top_3_performers(self):  
        employees = []
        for i in [Emp1, Emp2, Emp3, Emp4, Emp5]:
            if i.PerformanceRating <=5:
                employees.append(i)
            else:
                print(f"Employee ID: {i.EmployeeID} has an invalid Performance Rating of {i.PerformanceRating}. Skipping this employee.")
        top_3  = sorted(employees,key = lambda s : s.PerformanceRating, reverse = True)
        for i in top_3[:3]:
            top_3.sort(key = lambda x :x.DateOfJoining)
            print(f"Employee ID: {i.EmployeeID}, Performance Rating: {i.PerformanceRating}, Date of Joining: {i.DateOfJoining}")


Emp1 = Information(1, "Female", 60000, 5, "2022-05-10")
Emp2 = Information(2, "Male", 55000, 6, "2021-03-15")
Emp3 = Information(3, "Female", 70000, 4, "2020-11-20")
Emp4 = Information(4, "Male", 65000, 3, "2019-08-05")   
Emp5 = Information(5, "Female", 72000, 5, "2023-01-01")
Emp1.get_details()
Emp2.get_details()  
Emp3.get_details()
Emp4.get_details()
Emp5.get_details()
# Information.readData(Emp1)
Emp1.get_details()
Information.top_3_performers(Emp1)
# Out:
# EmployeeID: 1
# Gender: Female
# Salary: 60000
# Date of Joining: 2022-05-10
# EmployeeID: 2
# Gender: Male
# Salary: 55000
# PerformanceRating: 6 Cant be greater than 5
# Date of Joining: 2021-03-15
# EmployeeID: 3
# Gender: Female
# Salary: 70000
# Date of Joining: 2020-11-20
# EmployeeID: 4
# Gender: Male
# Salary: 65000
# Date of Joining: 2019-08-05
# EmployeeID: 5
# Gender: Female
# Salary: 72000
# Date of Joining: 2023-01-01
# EmployeeID: 1
# Gender: Female
# Salary: 60000
# Date of Joining: 2022-05-10
# Employee ID: 2 has an invalid Performance Rating of 6. Skipping this employee.
# Employee ID: 1, Performance Rating: 5, Date of Joining: 2022-05-10
# Employee ID: 5, Performance Rating: 5, Date of Joining: 2023-01-01
# Employee ID: 3, Performance Rating: 4, Date of Joining: 2020-11-20
